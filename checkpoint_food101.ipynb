# %% [markdown]
# # Checkpoint — Classificação de Imagens + Deploy
#
# Leia o `README.md` antes de começar.

# %%
from pathlib import Path

DATASET_ROOT = Path.cwd() / "food101_dataset"

CLASSES = [
    "apple_pie",
    "baklava",
    "beef_carpaccio",
    "beef_tartare",
    "beet_salad",
    "beignets",
]
TRAIN_PER_CLASS = 120
VAL_PER_CLASS = 40
TEST_PER_CLASS = 40

TRAIN_DIR = DATASET_ROOT / "train"
VAL_DIR = DATASET_ROOT / "val"
TEST_DIR = DATASET_ROOT / "test"

print("Dataset root:", DATASET_ROOT)
print("Existe:", DATASET_ROOT.exists())
print("Classes:", CLASSES)
print("Train folders:", len(list(TRAIN_DIR.iterdir())))
print("Val folders:", len(list(VAL_DIR.iterdir())))
print("Test folders:", len(list(TEST_DIR.iterdir())))
# Out:
# Dataset root: /Users/arnaldoalvesvianajunior/Downloads/checkpoint_aluno/food101_dataset
# Existe: True
# Classes: ['apple_pie', 'baklava', 'beef_carpaccio', 'beef_tartare', 'beet_salad', 'beignets']
# Train folders: 7
# Val folders: 7
# Test folders: 7

# %% [markdown]
# ## Sua solução
#
# A partir daqui, desenvolva sua solução. Adicione quantas células forem necessárias.

# %%
# Desenvolva sua solução a partir daqui.
